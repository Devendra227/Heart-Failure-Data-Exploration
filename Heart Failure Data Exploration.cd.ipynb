# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings ('ignore')

# %%
df=pd.read_csv("D:\\data science\\heart_failure_clinical_records_dataset.csv")
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.shape
# Out:
# (299, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df[df.duplicated]
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),cmap='Reds',annot=True)
plt.show()

# %%
high_blood_pressure_patients = df[df['high_blood_pressure']==1]

# %%
high_blood_pressure_patients
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# ..    ...      ...                       ...       ...                ...
# 255  52.0        1                       191         1                 30
# 257  58.0        0                       132         1                 38
# 270  44.0        0                       582         1                 30
# 275  45.0        0                       582         0                 38
# 294  62.0        0                        61         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each value in the 'high_blood_pressure' column
high_blood_pressure_counts = df['high_blood_pressure'].value_counts()

# Define labels based on unique values in 'high_blood_pressure'
labels = high_blood_pressure_counts.index.map(lambda x: 'High Blood Pressure' if x == 1 else 'No High Blood Pressure')

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(high_blood_pressure_counts, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff'])
plt.title('Distribution of High Blood Pressure')
plt.axis('equal')  # Equal aspect ratio ensures the pie is drawn as a circle.
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each value in the 'high_blood_pressure' column
high_blood_pressure_counts = df['high_blood_pressure'].value_counts()

# Define labels based on unique values in 'high_blood_pressure'
labels = ['No High Blood Pressure', 'High Blood Pressure']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(labels, high_blood_pressure_counts, color=['#66b3ff', '#ff9999'])
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count of High Blood Pressure')
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each value in the 'DEATH_EVENT' column
death_event_counts = df['DEATH_EVENT'].value_counts()

# Define labels based on unique values in 'DEATH_EVENT'
labels = ['No-Heartfailure', 'Heartfailure']

# Create a bar plot
plt.figure(figsize=(8, 6))
plt.bar(labels, death_event_counts, color=['#66b3ff', '#ff9999'])
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.title('Count of Heart Failure Outcomes')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.pie(df['DEATH_EVENT'].value_counts(),labels=['No-Heartfailure','Heartfailure'],autopct='%1.1f%%')
plt.title('Pie chart of Outcome')
plt.show()

# %%
average_age = df['age'].mean()

# %%
average_age
# Out:
# 60.83389297658862

# %% [markdown]
# ## Identify  the best random state number

# %%
X = df.drop('DEATH_EVENT', axis=1)
y = df['DEATH_EVENT']

# %%
Train =  []
Test = []
CV = []

for i in range (0,101):
    from sklearn.model_selection import train_test_split
    X_train , X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=i)

    from sklearn.linear_model import LogisticRegression
    log_default = LogisticRegression()
    log_default.fit(X_train,y_train)

    ypred_train = log_default.predict(X_train)
    ypred_test =  log_default.predict(X_test)

    from sklearn.metrics import accuracy_score
    Train.append(accuracy_score(y_train,ypred_train))
    Test.append(accuracy_score(y_test,ypred_test))
    
    from sklearn.model_selection import cross_val_score
    CV.append(cross_val_score(log_default,X_train,y_train,cv=5,scoring="accuracy").mean())
    
em = pd.DataFrame({"Train":Train,"Test":Test,"CV":CV})   
gm = em[(abs(em['Train']-em['Test'])<=0.5) & (abs(em['Test']-em['CV'])<=0.05)]
rs = gm[gm["CV"]==gm["CV"].max()].index.to_list()[0]
print("best random_state number:",rs)
# Out:
# best random_state number: 46

# %% [markdown]
# ##  train-test split

# %%
from sklearn.model_selection import train_test_split
X_train , X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2 , random_state=46)

# %% [markdown]
# ##  Machine Learning Modelling & Evaluation

# %% [markdown]
# ## LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression 
log_model = LogisticRegression()
log_model.fit(X_train,y_train)

ypred_train = log_model.predict(X_train)
ypred_test = log_model.predict(X_test)

print("Train Accuracy :",accuracy_score(y_train,ypred_train))
print("Cross validation score:",cross_val_score(log_model,X_train,y_train,cv=5,scoring = "accuracy"))
print("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.8451882845188284
# Cross validation score: [0.8125     0.79166667 0.89583333 0.875      0.85106383]
# Test Accuracy : 0.8

# %% [markdown]
# ##  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

estimator = KNeighborsClassifier()
param_grid = {'n_neighbors':list(range(1,50))}

from sklearn.model_selection import GridSearchCV
knn_grid = GridSearchCV(estimator,param_grid,scoring='accuracy',cv=5)
knn_grid.fit(X_train,y_train)

knn_model = knn_grid.best_estimator_

ypred_train = knn_model.predict(X_train)
ypred_test = knn_model.predict(X_test)

print ("Train Accuracy :",accuracy_score(y_train,ypred_train))
print ("Cross validation score:",cross_val_score(knn_model,X_train,y_train,cv=5,scoring="accuracy"))
print ("Test Accuracy :",accuracy_score(y_test,ypred_test))
# Out:
# Train Accuracy : 0.7112970711297071
# Cross validation score: [0.70833333 0.70833333 0.70833333 0.70833333 0.70212766]
# Test Accuracy : 0.5833333333333334
